# %% [markdown]
# <a href="https://colab.research.google.com/github/ladijadi/Projet_score-octroi/blob/main/1_Construire_Un_Score_Partie_1_2_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Base de Données pour le Projet de Scoring
#
# Le jeu de données utilisé dans ce projet est le "Default of Credit Card Clients Dataset" provenant de Taiwan (2005). Il contient des informations démographiques, financières ainsi que l’historique des paiements et des relevés de facturation des clients de cartes de crédit. Ces données serviront à développer un modèle de scoring pour prédire la probabilité de défaut de paiement.
#
# ## Description des Variables

# %% [markdown]
# # Projet de Scoring
#
# ## Contexte du Projet
#
# Les institutions financières doivent évaluer précisément le risque de défaut des clients avant d’octroyer du crédit. Ce projet utilise le jeu de données de Taiwan (2005) qui contient des informations démographiques, le crédit accordé, l’historique de paiement ainsi que les montants des factures et paiements. L'objectif est de développer un modèle de scoring qui prédit la probabilité de défaut de paiement le mois suivant, afin d’optimiser la gestion du risque et la prise de décision en matière d’octroi de crédit.
#
# ## Objectifs
#
# - **Analyser et comprendre** le profil des clients à risque.
# - **Identifier les variables clés** influençant le défaut de paiement.
# - **Construire et valider un modèle prédictif** (ex. régression logistique, arbres de décision, gradient boosting).
# - **Mettre en place un système de scoring** intégré dans le processus décisionnel.
#
# ## Étapes Clés du Projet
#
# 1. **Définition du Problème & Recueil des Exigences**
#    - Comprendre le besoin métier.
#    - Analyser l'existant
#    - Définir les indicateurs de performance (AUC, précision, etc.) et fixer les objectifs.
#
# 2. **Collecte et Préparation des Données**
#    - Importer le jeu de données.
#    - Nettoyer les données : gestion des valeurs manquantes, outliers, et incohérences.
#
# 3. **Exploration des Données (EDA)**
#    - Analyser les distributions des variables et visualiser les corrélations.
#
#
# 4. **Feature Engineering et Feature Selection**
#    - Créer de nouvelles variables (ex. ratios, agrégations) pour enrichir le modèle.
#    - Transformer et normaliser/standardiser les données.
#   - Identifier les variables pertinentes pour la prédiction.
#
# 5. **Modélisation**
#    - Séparer le jeu de données en ensembles d’entraînement et de test.
#    - Entraîner plusieurs modèles de classification.
#    - Optimiser les hyperparamètres par validation croisée.
#
# 6. **Évaluation du Modèle**
#    - Évaluer les performances (AUC, F1-score, etc.).
#    - Analyser l’importance des variables.
#
# 7. **Déploiement et Suivi**
#    - Intégrer le modèle dans un environnement de production.
#    - Mettre en place un suivi régulier et un système de recalibrage du scoring.

# %% [markdown]
# | **Variable**                    | **Description**                                                                                                                       |
# |---------------------------------|---------------------------------------------------------------------------------------------------------------------------------------|
# | **ID**                          | Identifiant unique du client.                                                                                                         |
# | **LIMIT_BAL**                   | Montant du crédit accordé en dollars NT (inclut crédit individuel et familial/supplémentaire).                                         |
# | **SEX**                         | Genre du client (1 = homme, 2 = femme).                                                                                               |
# | **EDUCATION**                   | Niveau d’éducation (1 = école supérieure, 2 = université, 3 = lycée, 4 = autres, 5 = inconnu, 6 = inconnu).                           |
# | **MARRIAGE**                    | Statut matrimonial (1 = marié, 2 = célibataire, 3 = autres).                                                                         |
# | **AGE**                         | Âge du client en années.                                                                                                               |
# | **PAY_0**                       | Statut de paiement en septembre 2005 (-1 = paiement à temps, 1 = retard d’un mois, 2 = retard de deux mois, …, 9 = retard de neuf mois ou plus). |
# | **PAY_2**                       | Statut de paiement en août 2005 (même échelle que PAY_0).                                                                             |
# | **PAY_3**                       | Statut de paiement en juillet 2005 (même échelle que PAY_0).                                                                            |
# | **PAY_4**                       | Statut de paiement en juin 2005 (même échelle que PAY_0).                                                                               |
# | **PAY_5**                       | Statut de paiement en mai 2005 (même échelle que PAY_0).                                                                                |
# | **PAY_6**                       | Statut de paiement en avril 2005 (même échelle que PAY_0).                                                                              |
# | **BILL_AMT1**                   | Montant de la facture pour septembre 2005 (en dollars NT).                                                                              |
# | **BILL_AMT2**                   | Montant de la facture pour août 2005 (en dollars NT).                                                                                   |
# | **BILL_AMT3**                   | Montant de la facture pour juillet 2005 (en dollars NT).                                                                                |
# | **BILL_AMT4**                   | Montant de la facture pour juin 2005 (en dollars NT).                                                                                   |
# | **BILL_AMT5**                   | Montant de la facture pour mai 2005 (en dollars NT).                                                                                    |
# | **BILL_AMT6**                   | Montant de la facture pour avril 2005 (en dollars NT).                                                                                  |
# | **PAY_AMT1**                    | Montant du paiement effectué en septembre 2005 (en dollars NT).                                                                         |
# | **PAY_AMT2**                    | Montant du paiement effectué en août 2005 (en dollars NT).                                                                              |
# | **PAY_AMT3**                    | Montant du paiement effectué en juillet 2005 (en dollars NT).                                                                           |
# | **PAY_AMT4**                    | Montant du paiement effectué en juin 2005 (en dollars NT).                                                                              |
# | **PAY_AMT5**                    | Montant du paiement effectué en mai 2005 (en dollars NT).                                                                               |
# | **PAY_AMT6**                    | Montant du paiement effectué en avril 2005 (en dollars NT).                                                                             |
# | **default.payment.next.month**  | Indicateur de défaut de paiement pour le mois suivant (1 = oui, 0 = non).                                                               |

# %% [markdown]
# # Etape 1: Définition de la problème
# Mise en place d'un score d'octroi

# %% [markdown]
# # Etape 2: Collecte et exploration des données

# %%
import pandas as pd

# Chargement des données (le fichier .csv est supposé disponible localement)
data = pd.read_csv('/content/UCI_Credit_Card.csv')  # nom fictif du fichier
print(data.shape)       # dimensions
# Out:
# (30000, 25)

# %%
print(data.columns)     # noms de colonnes
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default.payment.next.month'],
#       dtype='object')

# %%
data.head(5)    # aperçu des 5 premières lignes
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  float64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  float64
# ...

# %%
data.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  float64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  float64
# ...

# %%
# Transformation des données
categorical_columns = ['SEX', 'EDUCATION', 'MARRIAGE', 'PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'default.payment.next.month']

for col in categorical_columns:
    data[col] = data[col].astype('object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  float64
#  2   SEX                         30000 non-null  object
#  3   EDUCATION                   30000 non-null  object
#  4   MARRIAGE                    30000 non-null  object
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  object
#  7   PAY_2                       30000 non-null  object
#  8   PAY_3                       30000 non-null  object
#  9   PAY_4                       30000 non-null  object
#  10  PAY_5                       30000 non-null  object
#  11  PAY_6                       30000 non-null  object
#  12  BILL_AMT1                   30000 non-null  float64
# ...

# %% [markdown]
# ###  **Identification et traitement des Valeurs Manquantes**
# Avant toute modélisation, il est crucial d'identifier les valeurs manquantes afin d'éviter les erreurs et les biais dans les prédictions.

# %%
import pandas as pd
import numpy as np



# Affichage des valeurs manquantes par colonne
print(data.isnull().sum())
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default.payment.next.month    0
# dtype: int64

# %%
# Calcul du pourcentage de valeurs manquantes par colonne
missing_percent = data.isnull().sum() / len(data) * 100
print(missing_percent)
# Out:
# ID                            0.0
# LIMIT_BAL                     0.0
# SEX                           0.0
# EDUCATION                     0.0
# MARRIAGE                      0.0
# AGE                           0.0
# PAY_0                         0.0
# PAY_2                         0.0
# PAY_3                         0.0
# PAY_4                         0.0
# PAY_5                         0.0
# PAY_6                         0.0
# BILL_AMT1                     0.0
# BILL_AMT2                     0.0
# BILL_AMT3                     0.0
# BILL_AMT4                     0.0
# BILL_AMT5                     0.0
# BILL_AMT6                     0.0
# PAY_AMT1                      0.0
# PAY_AMT2                      0.0
# PAY_AMT3                      0.0
# PAY_AMT4                      0.0
# PAY_AMT5                      0.0
# PAY_AMT6                      0.0
# default.payment.next.month    0.0
# dtype: float64

# %% [markdown]
# ###  **Analyse des Valeurs Manquantes**
#
#
# Une fois les valeurs manquantes identifiées, il est important de déterminer leur nature et leur cause :
# - **Aléatoires (MCAR - Missing Completely At Random)** : Absences ponctuelles sans raison apparente.
# - **Non aléatoires (MAR - Missing At Random)** : Problème de collecte ou de stockage des données (ex. champs non remplis volontairement, erreurs de saisie).
# - **Systématiques (MNAR - Missing Not At Random)** : Certaines variables ont des valeurs absentes pour des groupes particuliers (ex. revenus non déclarés pour les auto-entrepreneurs).

# %%
# !pip install missingno

import missingno as msno
import matplotlib.pyplot as plt
# Visualisation des valeurs manquantes
msno.matrix(data)
plt.show()

# %%
msno.heatmap(data)
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/matrix.py:309: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# /usr/local/lib/python3.11/dist-packages/seaborn/matrix.py:309: UserWarning: Attempting to set identical low and high ylims makes transformation singular; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))

# %% [markdown]
# ###  **Traitement des Valeurs Manquantes**
#
# Selon la nature et l'importance des valeurs manquantes, différentes stratégies peuvent être employées :
#
# | Méthode | Description | Avantages | Inconvénients |
# |----------|------------|-----------|--------------|
# | Suppression des lignes | Supprime les observations contenant des valeurs manquantes | Simple, efficace si peu de valeurs manquantes | Risque de perte d'information si trop de lignes supprimées |
# | Suppression des colonnes | Supprime les variables contenant trop de valeurs manquantes | Pratique si la colonne est peu utile | Perte d'information si la variable est importante |
# | Imputation par la moyenne/médiane | Remplace par la moyenne/médiane des valeurs existantes | Simple, efficace pour les variables continues | Peut biaiser les données, ne conserve pas la variance |
# | Imputation par la valeur la plus fréquente | Remplace par la valeur la plus courante | Utile pour les variables catégoriques | Peut déformer la distribution |
# | Imputation par modèle (KNN, régression) | Prédit la valeur manquante en fonction des autres variables | Plus précis, conserve les relations entre variables | Plus coûteux en calcul, risque d'overfitting |
# | Imputation avec un indicateur de valeur manquante | Ajoute une catégorie "valeur manquante" pour les variables catégoriques ou une valeur extrême (ex. -999) pour les numériques | Permet de capturer l'information de la valeur manquante | Peut induire des artefacts dans le modèle |
# | Utilisation de SMOTE pour compenser | Génère des observations synthétiques pour combler les lacunes | Améliore les performances des modèles sur des données déséquilibrées | Augmente le temps de calcul |

# %% [markdown]
# ##  Méthodes de Détection des Valeurs Aberrantes
#
# | Méthode | Description | Formule |
# |---------|------------|----------|
# | **Z-score** | Détecte les valeurs situées à plus de 3 écarts-types de la moyenne. | \( Z = \frac{x - \mu}{\sigma} \) où \( \mu \) est la moyenne et \( \sigma \) l'écart-type |
# | **IQR (Interquartile Range)** | Détecte les valeurs en dehors de \([Q1 - 1.5 \times IQR, Q3 + 1.5 \times IQR]\). | \( IQR = Q3 - Q1 \) et les outliers sont \( x < Q1 - 1.5 \times IQR \) ou \( x > Q3 + 1.5 \times IQR \) |
# | **Boxplot** | Identifie visuellement les valeurs aberrantes dans un diagramme en boîte. | Basé sur IQR, les points hors des moustaches sont des outliers. |
# | **Isolation Forest** | Identifie les valeurs isolées par des arbres de décision aléatoires. | Basé sur l'isolement plus rapide des anomalies dans l'espace des features. |
# | **Local Outlier Factor (LOF)** | Détecte les anomalies en comparant la densité locale d’un point à celle de ses voisins. | LOF élevé indique un outlier. |
# | **One-Class SVM** | Apprend une frontière englobant les données normales et détecte les anomalies. | Utilise un hyperplan pour séparer les outliers. |
# | **DBSCAN** | Détecte les outliers comme des points hors clusters denses. | Les points sans voisins suffisants sont considérés comme bruit. |
#
# ##  Traitement des Valeurs Aberrantes
#
# | Méthode | Description | Avantages | Inconvénients |
# |---------|------------|-----------|--------------|
# | **Suppression des valeurs aberrantes** | Élimination des valeurs identifiées comme extrêmes. | Simple et efficace si peu d'outliers. | Risque de perte d'information si trop de valeurs supprimées. |
# | **Transformation logarithmique** | Applique une transformation log pour réduire l'impact des valeurs extrêmes. | Utile pour normaliser une distribution asymétrique. | Non applicable aux valeurs négatives ou nulles. |
# | **Winsorization** | Remplace les valeurs extrêmes par un seuil défini (ex. 5e et 95e percentile). | Réduit l’impact des outliers tout en conservant toutes les observations. | Peut biaiser l’analyse si mal calibré. |
# | **Imputation par la médiane ou la moyenne** | Remplace les valeurs aberrantes par la médiane ou la moyenne des autres observations. | Simple et rapide. | Peut fausser la distribution des données. |
# | **Remplacement par un modèle prédictif** | Utilisation d’un modèle (ex. régression, KNN) pour estimer et remplacer les valeurs extrêmes. | Conserve la cohérence des données. | Peut être complexe à mettre en œuvre et risque de sur-apprentissage. |
#
# Ces méthodes permettent de traiter efficacement les valeurs aberrantes afin d'améliorer la qualité et la robustesse des modèles d'analyse et de prédiction.

# %% [markdown]
# # Etape 3: EDA

# %% [markdown]
# ## Description des variables numériques

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

def analyze_numeric_variables(data):
    """
    Analyse les variables quantitatives d'une base de données :
    - Moyenne, médiane, écart type, minimum, maximum, quartiles
    - Boxplot, histogramme et QQ-plot
    """
    # Sélection des variables numériques
    numeric_vars = data.select_dtypes(include=['number'])

    # Calcul des statistiques descriptives
    stats_summary = numeric_vars.describe().T
    stats_summary['median'] = numeric_vars.median()

    print("\n📊 Statistiques descriptives des variables numériques :")
    print(stats_summary)

    # Visualisation des distributions
    for col in numeric_vars.columns:
        plt.figure(figsize=(15, 5))

        # Boxplot
        plt.subplot(1, 3, 1)
        sns.boxplot(y=numeric_vars[col], color='lightblue')
        plt.title(f'Boxplot de {col}')

        # Histogramme
        plt.subplot(1, 3, 2)
        sns.histplot(numeric_vars[col], bins=30, kde=True, edgecolor='black')
        plt.title(f'Histogramme de {col}')
        plt.xlabel(col)

        # QQ-Plot
        plt.subplot(1, 3, 3)
        stats.probplot(numeric_vars[col].dropna(), dist="norm", plot=plt)
        plt.title(f'QQ-Plot de {col}')

        plt.tight_layout()
        plt.show()

    return stats_summary

# %%
# Description des variables quantitatives
# Analyse des variables numériques
stats_summary = analyze_numeric_variables(data)
# Out:
# 📊 Statistiques descriptives des variables numériques :
#              count           mean            std       min       25%  \
# ID         30000.0   15000.500000    8660.398374       1.0   7500.75
# LIMIT_BAL  30000.0  167484.322667  129747.661567   10000.0  50000.00
# AGE        30000.0      35.485500       9.217904      21.0     28.00
# BILL_AMT1  30000.0   51223.330900   73635.860576 -165580.0   3558.75
# BILL_AMT2  30000.0   49179.075167   71173.768783  -69777.0   2984.75
# BILL_AMT3  30000.0   47013.154800   69349.387427 -157264.0   2666.25
# BILL_AMT4  30000.0   43262.948967   64332.856134 -170000.0   2326.75
# BILL_AMT5  30000.0   40311.400967   60797.155770  -81334.0   1763.00
# BILL_AMT6  30000.0   38871.760400   59554.107537 -339603.0   1256.00
# PAY_AMT1   30000.0    5663.580500   16563.280354       0.0   1000.00
# PAY_AMT2   30000.0    5921.163500   23040.870402       0.0    833.00
# PAY_AMT3   30000.0    5225.681500   17606.961470       0.0    390.00
# ...

# %% [markdown]
# # Description des variables qualitatives

# %%
def analyze_categorical_variables(data):
    """
    Analyse des variables qualitatives :
    - Tableau de fréquences
    - Diagramme en barres avec effectifs et proportions
    """
    categorical_vars = data.select_dtypes(include=['object','category'])

    for col in categorical_vars.columns:
        freq_table = data[col].value_counts()
        proportions = (freq_table / len(data) * 100).round(2)
        freq_df = pd.DataFrame({"Effectif": freq_table, "Proportion (%)": proportions})

        print(f"\n📊 Fréquence des modalités pour {col} :")
        print(freq_df)

        # Barplot
        plt.figure(figsize=(8, 5))
        ax = sns.countplot(x=data[col], palette='viridis', edgecolor='black')
        plt.title(f"Répartition des catégories - {col}")
        plt.xlabel(col)
        plt.ylabel("Nombre d'observations")
        plt.xticks(rotation=45)

        # Ajout des effectifs et proportions au-dessus des barres
        for p in ax.patches:
            height = p.get_height()
            ax.annotate(f'{height} ({(height/len(data)*100):.2f}%)',
                        (p.get_x() + p.get_width() / 2., height),
                        ha='center', va='bottom', fontsize=10, color='black')
        print("test")

        plt.show()

# %%
# Analyse des variables qualitatives
analyze_categorical_variables(data)
# Out:
# 📊 Fréquence des modalités pour SEX :
#      Effectif  Proportion (%)
# SEX
# 2       18112           60.37
# 1       11888           39.63
# <ipython-input-15-8402b44ae388>:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x=data[col], palette='viridis', edgecolor='black')
# test
# 📊 Fréquence des modalités pour EDUCATION :
#            Effectif  Proportion (%)
# EDUCATION
# 2             14030           46.77
# 1             10585           35.28
# 3              4917           16.39
# 5               280            0.93
# 4               123            0.41
# 6                51            0.17
# 0                14            0.05
# <ipython-input-15-8402b44ae388>:19: FutureWarning:
#
# ...

# %% [markdown]
# # Regroupement des Modalités Rares
#
#
# Lorsqu'une modalité apparaît avec une fréquence très faible (moins de 5%), elle peut poser des problèmes en modélisation et en interprétation des résultats. Il est donc pertinent de regrouper ces modalités en fonction de leur signification métier pour assurer la robustesse du modèle et améliorer l’analyse.
#
# ### 1️⃣ **Niveau d'éducation (EDUCATION)**
# - **Avant regroupement :** Plusieurs valeurs rares (`5`, `6`, `0`, `4`).
# - **Regroupement proposé :**
#   - `1` = "École supérieure"
#   - `2` = "Université"
#   - `3` = "Lycée"
#   - `5`, `6`, `0` → **"Inconnu"** (Ces valeurs ne permettent pas de distinguer un niveau de formation clair).
#   - `4` → **"Autres"** (Cette catégorie est trop vague mais peut inclure des formations non académiques).
#
# ### 2️⃣ **Statut matrimonial (MARRIAGE)**
# - **Avant regroupement :** Certaines valeurs rares (`3`, `0`).
# - **Regroupement proposé :**
#   - `1` = "Marié"
#   - `2` = "Célibataire"
#   - `3`, `0` → **"Autres"** (Cette catégorie peut inclure veufs, divorcés ou autres situations non définies).
#
# ### 3️⃣ **Statut de paiement des 6 derniers mois (PAY_0 à PAY_6)**
# - **Avant regroupement :** Large éventail de valeurs (-2 à 8), certaines rares.
# - **Regroupement proposé :**
#
#   - 1,2,3,4,5,6,7,8→ **"Retard "**

# %%
# Regroupement des modalités rares avec une logique métier
data['EDUCATION'] = data['EDUCATION'].replace({5: 'Autres', 6: 'Autres', 0: 'Autres', 4: 'Autres'})

# Regroupement des statuts matrimoniaux
data['MARRIAGE'] = data['MARRIAGE'].replace({3: 'Autres', 0: 'Autres'})

# Regroupement des statuts de paiement
pay_columns = ['PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6']
for col in pay_columns:
    data[col] = data[col].replace({-2: 'Paiement à temps', -1: 'Paiement à temps', 0: 'Paiement à temps',
                                    1: 'Retard', 2: 'Retard',
                                    3: 'Retard', 4: 'Retard', 5: 'Retard',
                                    6: 'Retard', 7: 'Retard', 8: 'Retard'})

# %%
# Analyse des variables qualitatives
analyze_categorical_variables(data)
# Out:
# 📊 Fréquence des modalités pour SEX :
#      Effectif  Proportion (%)
# SEX
# 2       18112           60.37
# 1       11888           39.63
# test
# <ipython-input-15-8402b44ae388>:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x=data[col], palette='viridis', edgecolor='black')
# 📊 Fréquence des modalités pour EDUCATION :
#            Effectif  Proportion (%)
# EDUCATION
# 2             14030           46.77
# 1             10585           35.28
# 3              4917           16.39
# Autres          468            1.56
# test
# <ipython-input-15-8402b44ae388>:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x=data[col], palette='viridis', edgecolor='black')
# ...
